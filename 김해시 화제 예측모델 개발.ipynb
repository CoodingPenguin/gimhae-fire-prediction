# %% [markdown]
# # 김해시 화제 예측모델 개발
# ## 1. 데이터 로드

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model, preprocessing, svm
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler
import math
import matplotlib
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings; warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train = pd.read_csv('./data/PJT002_train.csv')
#df_val = pd.read_csv('./data/PJT002_validation.csv')
df_test = pd.read_csv('./data/PJT002_test.csv')

# %%
df_train.rename(columns={'fr_yn':'fr_yn1'}, inplace=True)
df_train['fr_yn'] = df_train['fr_yn1']
df_train.drop('fr_yn1', axis=1, inplace=True)
df_train.head()
# Out:
#            dt_of_fr bldng_us bldng_archtctr  bldng_cnt  bldng_ar   ttl_ar  \
# 0  2017-10-20 05:54     단독주택           블록구조          3     69.42    69.42
# 1  2018-09-30 08:26      NaN            NaN          3     46.29    46.29
# 2  2016-10-30 14:57     공동주택       철근콘크리트구조          1    583.80  2516.76
# 3  2016-06-14 05:23     단독주택          일반목구조          2     48.92    48.92
# 4  2018-04-22 05:38      NaN            NaN          2      0.00     0.00
#
#    lnd_ar dt_of_athrztn  ttl_grnd_flr  ttl_dwn_flr  ... bldng_cnt_in_50m  \
# 0     0.0          1977           1.0          0.0  ...                0
# 1     0.0           NaN           1.0          0.0  ...                0
# 2  1446.0   2.00011e+07           5.0          0.0  ...               14
# 3     0.0          1936           1.0          0.0  ...               11
# 4     0.0           NaN           NaN          NaN  ...                0
#
#    trgt_crtr  fr_fghtng_fclt_spcl_css_5_yn  fr_fghtng_fclt_spcl_css_6_yn  \
# 0        NaN                           NaN                           NaN
# 1        NaN                           NaN                           NaN
# 2        NaN                           NaN                           NaN
# 3        NaN                           NaN                           NaN
# 4        NaN                           NaN                           NaN
#
#    us_yn  dngrs_thng_yn  slf_fr_brgd_yn  blk_dngrs_thng_mnfctr_yn  \
# 0    NaN            NaN             NaN                       NaN
# 1    NaN            NaN             NaN                       NaN
# 2    NaN            NaN             NaN                       NaN
# 3    NaN            NaN             NaN                       NaN
# 4    NaN            NaN             NaN                       NaN
#
#    cltrl_hrtg_yn  fr_yn
# 0            NaN      Y
# 1            NaN      N
# 2            NaN      Y
# 3            NaN      N
# 4            NaN      N
#
# [5 rows x 180 columns]

# %%
df_test.head()
# Out:
#            dt_of_fr bldng_us bldng_archtctr  bldng_cnt  bldng_ar   ttl_ar  \
# 0  2016-02-03 15:28      NaN            NaN          3      0.00     0.00
# 1  2016-03-17 18:25       공장         일반철골구조          2    915.75   903.75
# 2  2018-12-03 06:51      NaN            NaN          5   5523.87  9888.87
# 3  2015-03-29 23:37      NaN            NaN          8    667.20   914.40
# 4  2016-05-17 11:08      NaN            NaN          7   1050.06  1050.33
#
#     lnd_ar  dt_of_athrztn  ttl_grnd_flr  ttl_dwn_flr  ... bldng_cnt_in_50m  \
# 0      0.0            NaN           NaN          NaN  ...                0
# 1   2660.0     20011228.0           1.0          0.0  ...                8
# 2  13607.0            NaN           9.0          0.0  ...                1
# 3      0.0            NaN           3.0          0.0  ...                0
# 4      0.0            NaN           3.0          0.0  ...                4
#
#    trgt_crtr  fr_fghtng_fclt_spcl_css_5_yn  fr_fghtng_fclt_spcl_css_6_yn  \
# 0        NaN                           NaN                           NaN
# 1        NaN                           NaN                           NaN
# 2        NaN                             N                             N
# 3        NaN                           NaN                           NaN
# 4        NaN                           NaN                           NaN
#
#    us_yn  dngrs_thng_yn  slf_fr_brgd_yn  blk_dngrs_thng_mnfctr_yn  \
# 0    NaN            NaN             NaN                       NaN
# 1    NaN            NaN             NaN                       NaN
# 2      N              N               N                         N
# 3    NaN            NaN             NaN                       NaN
# 4    NaN            NaN             NaN                       NaN
#
#    cltrl_hrtg_yn  fr_yn
# 0            NaN    NaN
# 1            NaN    NaN
# 2              N    NaN
# 3            NaN    NaN
# 4            NaN    NaN
#
# [5 rows x 180 columns]

# %%
df_train.shape
# Out:
# (59199, 180)

# %%
df_train.info(True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59199 entries, 0 to 59198
# Data columns (total 180 columns):
# dt_of_fr                        object
# bldng_us                        object
# bldng_archtctr                  object
# bldng_cnt                       int64
# bldng_ar                        float64
# ttl_ar                          float64
# lnd_ar                          float64
# dt_of_athrztn                   object
# ttl_grnd_flr                    float64
# ttl_dwn_flr                     float64
# bldng_us_clssfctn               object
# tmprtr                          float64
# prcpttn                         float64
# wnd_spd                         float64
# wnd_drctn                       float64
# hmdt                            float64
# gas_engry_us_201401             float64
# ele_engry_us_201401             float64
# gas_engry_us_201402             float64
# ele_engry_us_201402             float64
# gas_engry_us_201403             float64
# ele_engry_us_201403             float64
# gas_engry_us_201404             float64
# ele_engry_us_201404             float64
# gas_engry_us_201405             float64
# ele_engry_us_201405             float64
# gas_engry_us_201406             float64
# ele_engry_us_201406             float64
# gas_engry_us_201407             float64
# ele_engry_us_201407             float64
# gas_engry_us_201408             float64
# ele_engry_us_201408             float64
# gas_engry_us_201409             float64
# ele_engry_us_201409             float64
# gas_engry_us_201410             float64
# ele_engry_us_201410             float64
# gas_engry_us_201411             float64
# ele_engry_us_201411             float64
# gas_engry_us_201412             float64
# ele_engry_us_201412             float64
# gas_engry_us_201501             float64
# ele_engry_us_201501             float64
# gas_engry_us_201502             float64
# ele_engry_us_201502             float64
# gas_engry_us_201503             float64
# ele_engry_us_201503             float64
# gas_engry_us_201504             float64
# ele_engry_us_201504             float64
# gas_engry_us_201505             float64
# ele_engry_us_201505             float64
# gas_engry_us_201506             float64
# ele_engry_us_201506             float64
# gas_engry_us_201507             float64
# ele_engry_us_201507             float64
# gas_engry_us_201508             float64
# ele_engry_us_201508             float64
# gas_engry_us_201509             float64
# ele_engry_us_201509             float64
# gas_engry_us_201510             float64
# ele_engry_us_201510             float64
# gas_engry_us_201511             float64
# ele_engry_us_201511             float64
# gas_engry_us_201512             float64
# ele_engry_us_201512             float64
# gas_engry_us_201601             float64
# ele_engry_us_201601             float64
# gas_engry_us_201602             float64
# ele_engry_us_201602             float64
# gas_engry_us_201603             float64
# ele_engry_us_201603             float64
# gas_engry_us_201604             float64
# ele_engry_us_201604             float64
# gas_engry_us_201605             float64
# ele_engry_us_201605             float64
# gas_engry_us_201606             float64
# ele_engry_us_201606             float64
# gas_engry_us_201607             float64
# ele_engry_us_201607             float64
# gas_engry_us_201608             float64
# ele_engry_us_201608             float64
# gas_engry_us_201609             float64
# ele_engry_us_201609             float64
# gas_engry_us_201610             float64
# ele_engry_us_201610             float64
# gas_engry_us_201611             float64
# ele_engry_us_201611             float64
# gas_engry_us_201612             float64
# ele_engry_us_201612             float64
# gas_engry_us_201701             float64
# ele_engry_us_201701             float64
# gas_engry_us_201702             float64
# ele_engry_us_201702             float64
# gas_engry_us_201703             float64
# ele_engry_us_201703             float64
# gas_engry_us_201704             float64
# ele_engry_us_201704             float64
# gas_engry_us_201705             float64
# ele_engry_us_201705             float64
# gas_engry_us_201706             float64
# ele_engry_us_201706             float64
# gas_engry_us_201707             float64
# ele_engry_us_201707             float64
# gas_engry_us_201708             float64
# ele_engry_us_201708             float64
# gas_engry_us_201709             float64
# ele_engry_us_201709             float64
# gas_engry_us_201710             float64
# ele_engry_us_201710             float64
# gas_engry_us_201711             float64
# ele_engry_us_201711             float64
# gas_engry_us_201712             float64
# ele_engry_us_201712             float64
# gas_engry_us_201801             float64
# ele_engry_us_201801             float64
# gas_engry_us_201802             float64
# ele_engry_us_201802             float64
# gas_engry_us_201803             float64
# ele_engry_us_201803             float64
# gas_engry_us_201804             float64
# ele_engry_us_201804             float64
# gas_engry_us_201805             float64
# ele_engry_us_201805             float64
# gas_engry_us_201806             float64
# ele_engry_us_201806             float64
# gas_engry_us_201807             float64
# ele_engry_us_201807             float64
# gas_engry_us_201808             float64
# ele_engry_us_201808             float64
# gas_engry_us_201809             float64
# ele_engry_us_201809             float64
# gas_engry_us_201810             float64
# ele_engry_us_201810             float64
# gas_engry_us_201811             float64
# ele_engry_us_201811             float64
# gas_engry_us_201812             float64
# ele_engry_us_201812             float64
# lw_13101010                     float64
# lw_13101110                     float64
# lw_13101210                     float64
# lw_13101211                     float64
# lw_13101310                     float64
# lw_13101410                     float64
# lw_13111010                     float64
# lw_13111110                     float64
# lw_13121010                     float64
# lw_13121011                     float64
# lw_13131010                     float64
# lw_13131110                     float64
# lw_13141010                     float64
# lw_13141011                     float64
# jmk                             object
# id                              int64
# rgnl_ar_nm                      object
# rgnl_ar_nm2                     object
# lnd_us_sttn_nm                  object
# rd_sd_nm                        object
# emd_nm                          object
# hm_cnt                          float64
# fr_sttn_dstnc                   int64
# bldng_ar_prc                    float64
# fr_wthr_fclt_dstnc              int64
# fr_mn_cnt                       float64
# mlt_us_yn                       object
# cctv_dstnc                      int64
# fr_wthr_fclt_in_100m            int64
# cctv_in_100m                    int64
# tbc_rtl_str_dstnc               int64
# sft_emrgnc_bll_dstnc            int64
# ahsm_dstnc                      int64
# no_tbc_zn_dstnc                 int64
# bldng_cnt_in_50m                int64
# trgt_crtr                       object
# fr_fghtng_fclt_spcl_css_5_yn    object
# fr_fghtng_fclt_spcl_css_6_yn    object
# us_yn                           object
# dngrs_thng_yn                   object
# slf_fr_brgd_yn                  object
# blk_dngrs_thng_mnfctr_yn        object
# cltrl_hrtg_yn                   object
# fr_yn                           object
# dtypes: float64(147), int64(12), object(21)
# memory usage: 81.3+ MB

# %%
# y or n -> 1 or 0
binary_y = {'N':0, 'Y':1}

df_train['fr_yn'] = df_train['fr_yn'].map(binary_y)
df_train['mlt_us_yn'] = df_train['mlt_us_yn'].map(binary_y)
# df_val['fr_yn'] = df_val['fr_yn'].map(binary_y)
# df_val['mlt_us_yn'] = df_val['mlt_us_yn'].map(binary_y)
df_test['fr_yn'] = df_test['fr_yn'].map(binary_y)
df_test['mlt_us_yn'] = df_test['mlt_us_yn'].map(binary_y)

# %% [markdown]
# ## 2. 데이터 가공

# %% [markdown]
# ### 2.1. 불필요한 피처 제거

# %%
def remove_feat(df):
    idx = [1, 3, 6, 11, 12, 13, 14] + list(range(16, 152)) + [153, 157, 158, 161, 163, 164, 166, 168] + list(range(170, 179))
    df.drop(df.iloc[:, idx], axis=1, inplace=True)

# %%
remove_feat(df_train)
# remove_feat(df_val)
remove_feat(df_test)

df_train.shape[1], df_test.shape[1]
# Out:
# (20, 20)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59199 entries, 0 to 59198
# Data columns (total 20 columns):
# dt_of_fr                59199 non-null object
# bldng_archtctr          31534 non-null object
# bldng_ar                59199 non-null float64
# ttl_ar                  59199 non-null float64
# dt_of_athrztn           31618 non-null object
# ttl_grnd_flr            48989 non-null float64
# ttl_dwn_flr             48194 non-null float64
# bldng_us_clssfctn       29856 non-null object
# hmdt                    59177 non-null float64
# rgnl_ar_nm              57708 non-null object
# lnd_us_sttn_nm          57423 non-null object
# rd_sd_nm                57708 non-null object
# emd_nm                  59195 non-null object
# bldng_ar_prc            37304 non-null float64
# fr_wthr_fclt_dstnc      59199 non-null int64
# mlt_us_yn               59199 non-null int64
# cctv_in_100m            59199 non-null int64
# sft_emrgnc_bll_dstnc    59199 non-null int64
# no_tbc_zn_dstnc         59199 non-null int64
# fr_yn                   59199 non-null int64
# dtypes: float64(6), int64(6), object(8)
# memory usage: 9.0+ MB

# %% [markdown]
# ### 2.2. 데이터 전처리

# %% [markdown]
# #### 2.2.1. 전처리를 위한 함수 정의
# ##### 모든 피처에 사용되는 함수

# %%
# 빈 칸으로 두 개의 데이터로 분리
def split_dt1(data):
    try:
        return data.split(' ')
    except:
        return['a','a']

# 빈 칸으로 두 개의 데이터로 분리
def split_dt2(data):
    try:
        return data.split(' ')
    except:
        return['a','a','a']

# -로 3개의 데이터로 분리
def split_ds(data):
    try:
        return data.split('-')
    except:
        return['b','b','b']

# :로 2개의 데이터로 분리
def split_dy(data):
    try:
        return data.split(':')
    except:
        return['c','c']

# %%
# 비숫자형 데이터를 인코딩
def encode_value(df, col_name):
    encoder = LabelEncoder()
    encoder.fit(df[col_name])
    labels = encoder.transform(df[col_name])
    df[col_name] = labels
    
    return df

# %% [markdown]
# ##### 개별 피처에 사용되는 함수

# %%
# bldng_archtctr 전처리 함수
def pre_bldng_archtctr(df):
    df['bldng_archtctr'].fillna(value='not-declared', inplace=True)
    encode_value(df,'bldng_archtctr')
    
    return df

# %%
# bldng_us_clssfctn 전처리 함수
def pre_bldng_us_clssfctn(df):
    df['bldng_us_clssfctn'].fillna(value='not-declared', inplace=True)
    encode_value(df,'bldng_us_clssfctn')
    
    return df

# %%
# rd_sd_nm 전처리 함수
def pre_rd_sd_nm(df):
    df['rd_sd_nm'].fillna('세로한면(가)', inplace=True)
    encode_value(df,'rd_sd_nm')
    return df

# %%
# fr_wthr_fclt_dstnc 전처리 함수
def pre_fr_wthr_fclt_dstnc(df):
    df['fr_wthr_fclt_dstnc']=(df['fr_wthr_fclt_dstnc']*0.1).round()
    return df

# %%
# dt_of_fr 전처리 함수
def pre_dt_of_fr(df):
    df['date'], df['time'] = zip(*df['dt_of_fr'].apply(lambda x:split_dt1(x)))
    df['year'], df['month'], df['day'] = zip(*df['date'].apply(lambda x:split_ds(x)))
    df['hour'], df['minute'] = zip(*df['time'].apply(lambda x:split_dy(x)))
    df.drop(['dt_of_fr','time','date','minute','year','day'], axis=1, inplace=True)
    
    return df

# %%
# hmdt 전처리 함수
def pre_hmdt(df):
    data=df
    data1=data[data['month'].isin(['01'])]
    data2=data[data['month'].isin(['02'])]
    data3=data[data['month'].isin(['03'])]
    data4=data[data['month'].isin(['04'])]
    data5=data[data['month'].isin(['05'])]
    data6=data[data['month'].isin(['06'])]
    data7=data[data['month'].isin(['07'])]
    data8=data[data['month'].isin(['08'])]
    data9=data[data['month'].isin(['09'])]
    data10=data[data['month'].isin(['10'])]
    data11=data[data['month'].isin(['11'])]
    data12=data[data['month'].isin(['12'])]
    data1['hmdt']=data1['hmdt'].fillna('54.28')
    data2['hmdt']=data2['hmdt'].fillna('51.23')
    data3['hmdt']=data3['hmdt'].fillna('58.02')
    data4['hmdt']=data4['hmdt'].fillna('61.95')
    data5['hmdt']=data5['hmdt'].fillna('61.74')
    data6['hmdt']=data6['hmdt'].fillna('71.57')
    data7['hmdt']=data7['hmdt'].fillna('80.00')
    data8['hmdt']=data8['hmdt'].fillna('77.88')
    data9['hmdt']=data9['hmdt'].fillna('77.61')
    data10['hmdt']=data10['hmdt'].fillna('72.29')
    data11['hmdt']=data11['hmdt'].fillna('68.90')
    data12['hmdt']=data12['hmdt'].fillna('57.36')
    data_fin=pd.concat([data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12])
    data_fin=data_fin.sort_index()
    data_fin[['hmdt','hour']] = data_fin[['hmdt','hour']].apply(pd.to_numeric)
    df[['hmdt','hour']]=data_fin[['hmdt','hour']]
    df.drop("month",axis=1,inplace=True)
    
    return df

# %%
# emd_nm 전처리 함수
def pre_emd_nm(df):
    df['emd_nm'].fillna(value="경상남도 창원시 의창구", inplace=True)
    df['a'], df['b'], df['c'] = zip(*df['emd_nm'].apply(lambda x:split_dt2(x)))
    df['emd_nm'] = df['a'] + df['b'] + df['c']
    df['emd_nm'] = df['emd_nm'].str[7:10]
    encode_value(df,'emd_nm')
    df.drop(['a','b','c'],axis=1,inplace=True)
    
    return df

# %%
# bldng_ar_prc 전처리 함수 
def pre_bldng_ar_prc(df):
    df1 = pd.DataFrame(columns=["emd_nm","bldng_ar_prc",'dt_of_athrztn'])
    df1.reset_index(inplace=True)
    df2 = df[['emd_nm',"bldng_ar_prc",'dt_of_athrztn']]

    for i in range(236):
        df3 = df2[df2['emd_nm'].isin([i])]
        avg = df3["bldng_ar_prc"].mean()
        df3['bldng_ar_prc'] = df3['bldng_ar_prc'].fillna(avg)
        df1 = df1.append(df3)
        
    avg = df2["bldng_ar_prc"].mean()
    df1['bldng_ar_prc'].fillna(value=avg, inplace=True)
    df1 = df1.sort_index()
    df["bldng_ar_prc"] = df1["bldng_ar_prc"]
    df["bldng_ar_prc"] = (df["bldng_ar_prc"]*0.001).round().astype(int)
    
    return df

# %%
# dt_of_arthrztn 전처리 함수1 : outlier 제거 및 null값 처리 및 건물 나이 계산
def pre_dt_of_athrztn(df):
    df['dt_of_athrztn'] = df['dt_of_athrztn'].fillna('1')
    df['dt_of_athrztn'] = df['dt_of_athrztn'].astype('str')
    df['dt_of_athrztn'] = df['dt_of_athrztn'].str[0:4]
    df[df['dt_of_athrztn'] > '2019']= 1
    df['dt_of_athrztn'] = 2019 - df['dt_of_athrztn'].astype('int')
    
    return df

# %%
# dt_of_arthrztn 전처리 함수2 : 건물 나이 계산
def pre2_dt_of_athrztn(df):
    df2 = pd.DataFrame(columns=["emd_nm","bldng_ar_prc",'dt_of_athrztn'])
    df2.reset_index(inplace=True)
    df3 = df[df['dt_of_athrztn'] != 2018]
    
    for i in range(236):
        df4 = df[df['emd_nm'].isin([i])]
        df5 = df3[df3['emd_nm'].isin([i])]
        avg = df5["dt_of_athrztn"].mean()
        df4[df4['dt_of_athrztn'] == 2018] = avg
        df2 = df2.append(df4)
        
    avg = df3["dt_of_athrztn"].mean()
    df2[df2['dt_of_athrztn'] == 2018] = avg
    df2 = df2.sort_values(by='index')
    df["dt_of_athrztn"] = df2["dt_of_athrztn"].round().astype('int')
    
    return df

# %%
# rgnl_ar_nm 전처리 함수
# null값을 '필드값없음'으로 만든 버전
def get_group_rgnl1(data): 
    cat=''
    if (data == "제1종일반주거지역") | (data == "제2종일반주거지역") | (data == "제3종일반주거지역")\
        | (data == "제1종전용주거지역") | (data == "제2종전용주거지역") | (data == "준주거지역"):
        cat='주거지역'
    elif (data == "계획관리지역") | (data == "관리지역") | (data == "보전관리지역") | (data == "생산관리지역"):
        cat='관리지역'
    elif (data == "보전녹지지역") | (data == "생산녹지지역") | (data == "자연녹지지역"):
        cat='녹지지역'
    elif (data == "근린상업지역") | (data == "유통상업지역") | (data == "일반상업지역") | (data == "중심상업지역"):
        cat='상업지역'
    elif (data == "일반공업지역") | (data == "준공업지역"):
        cat='공업지역'
    elif (data == "개발제한구역"):
        cat='개발제한구역'
    elif (data == "농림지역"):
        cat='농림지역'
    elif (data == "용도미지정"):
        cat='용도미지정'
    elif (data == "자연환경보전지역"):
        cat='자연환경보전지역'
    else:
        cat='필드값없음'
    
    return cat

# null값을 '관리지역'으로 만든버전
def get_group_rgnl2(data): 
    cat=''
    if (data == "제1종일반주거지역") | (data == "제2종일반주거지역") | (data == "제3종일반주거지역")\
        | (data == "제1종전용주거지역") | (data == "제2종전용주거지역") | (data == "준주거지역"):
            cat='주거지역'
    elif (data == "계획관리지역") | (data == "관리지역") | (data == "보전관리지역") | (data == "생산관리지역"):
        cat='관리지역'
    elif (data == "보전녹지지역") | (data == "생산녹지지역") | (data == "자연녹지지역"):
        cat='녹지지역'
    elif (data == "근린상업지역") | (data == "유통상업지역") | (data == "일반상업지역") | (data == "중심상업지역"):
        cat='상업지역'
    elif (data == "일반공업지역") | (data == "준공업지역"):
        cat='공업지역'
    elif (data == "개발제한구역"):
        cat='개발제한구역'
    elif (data == "농림지역"):
        cat='농림지역'
    elif (data == "용도미지정"):
        cat='용도미지정'
    elif (data == "자연환경보전지역"):
        cat='자연환경보전지역'
    else:
        cat='관리지역'
    
    return cat

def pre_rgnl_ar_nm(df):
    df['rgnl_ar_nm_cat'] = df['rgnl_ar_nm'].apply(get_group_rgnl1)
    df['rgnl_ar_nm_cat2'] = df['rgnl_ar_nm'].apply(get_group_rgnl2)
    encode_value(df,'rgnl_ar_nm_cat')
    encode_value(df, 'rgnl_ar_nm_cat2')
    df.drop('rgnl_ar_nm', axis=1, inplace=True)
    
    return df

# %%
# lnd_us_sttn_nm 전처리 함수
# null값을 '필드값없음'으로 만든 버전
def get_group_lnd1(data):
    cat=''
    if (data == "고속도로휴게소") | (data == "공원등") | (data == "도로등") | (data == "여객자동차터미널")\
        | (data == "운동장등") | (data == "위험시설") | (data == "유해.혐오시설") | (data == "주차장등")\
        | (data == "하천등"):
        cat='공공용지'
    elif (data == "골프장 대중제") | (data == "골프장 회원제") | (data == "공원묘지") | (data == "스키장")\
        | (data == "유원지") | (data == "콘도미니엄") | (data == "특수기타"):
        cat='특수토지'
    elif (data == "공업기타") | (data == "공업나지") | (data == "공업용") | (data == "발전소"):
        cat='공업용'
    elif (data == "과수원") | (data == "전") | (data == "전기타"):
        cat='전'
    elif (data == "기타"):
        cat='기타'
    elif (data == "다세대") | (data == "단독") | (data == "아파트") | (data == "연립") | (data == "주거기타")\
        | (data == "주거나지"):
        cat='주거용'
    elif (data == "답") | (data == "답기타"):
        cat='답'
    elif (data == "목장용지") | (data == "임야기타") | (data == "자연림") | (data == "조림")\
        | (data == "토지임야"):
        cat='임야'
    elif (data == "상업기타") | (data == "상업나지") | (data == "상업용") | (data == "업무용"):
        cat='상업업무용'
    elif (data == "주상기타") | (data == "주상나지") | (data == "주상용"):
        cat='주상복합용'
    else:
        cat='필드값없음'
    
    return cat

# null값 '주거용'으로 만든 버전
def get_group_lnd2(data): 
    cat=''
    if (data == "고속도로휴게소") | (data == "공원등") | (data == "도로등") | (data == "여객자동차터미널")\
        | (data == "운동장등") | (data == "위험시설") | (data == "유해.혐오시설") | (data == "주차장등")\
        | (data == "하천등"):
        cat='공공용지'
    elif (data == "골프장 대중제") | (data == "골프장 회원제") | (data == "공원묘지") | (data == "스키장")\
        | (data == "유원지") | (data == "콘도미니엄") | (data == "특수기타"):
        cat='특수토지'
    elif (data == "공업기타") | (data == "공업나지") | (data == "공업용") | (data == "발전소"):
        cat='공업용'
    elif (data == "과수원") | (data == "전") | (data == "전기타"):
        cat='전'
    elif (data == "기타"):
        cat='기타'
    elif (data == "다세대") | (data == "단독") | (data == "아파트") | (data == "연립")\
        | (data == "주거기타") | (data == "주거나지"):
        cat='주거용'
    elif (data == "답") | (data == "답기타"):
        cat='답'
    elif (data == "목장용지") | (data == "임야기타") | (data == "자연림") | (data == "조림")\
        | (data == "토지임야"):
        cat='임야'
    elif (data == "상업기타") | (data == "상업나지") | (data == "상업용") | (data == "업무용"):
        cat='상업업무용'
    elif (data == "주상기타") | (data == "주상나지") | (data == "주상용"):
        cat='주상복합용'
    else:
        cat='주거용'
    
    return cat

def pre_lnd_us_sttn(df):
    df['lnd_us_sttn_cat'] = df['lnd_us_sttn_nm'].apply(get_group_lnd1)
    df['lnd_us_sttn_cat2'] = df['lnd_us_sttn_nm'].apply(get_group_lnd2)
    encode_value(df,'lnd_us_sttn_cat')
    encode_value(df,'lnd_us_sttn_cat2')
    df.drop('lnd_us_sttn_nm', axis=1, inplace=True)
    
    return df

# %%
# ttl_ar 전처리 함수
def pre_ttl_ar(df):
    df['log_ttl_ar'] = df['ttl_ar'].apply(lambda x:int(np.log(x+1)))
    df.drop('ttl_ar', axis=1, inplace=True)
    
    df.loc[((df['log_ttl_ar']>=6) & (df['log_ttl_ar']<=8)), 'log_ttl_ar'] = 6
    df.loc[df['log_ttl_ar']>8, 'log_ttl_ar'] = 7
    
    return df

# %%
# bldng_ar 전처리 함수
def pre_bldng_ar(df):
    df['log_bldng_ar'] = df['bldng_ar'].apply(lambda x:int(np.log(x+1)))
    df.drop('bldng_ar', axis=1, inplace=True)
    
    df.loc[((df['log_bldng_ar']==5) | (df['log_bldng_ar']==6)), 'log_bldng_ar'] = 5
    df.loc[df['log_bldng_ar']==7, 'log_bldng_ar'] = 6
    df.loc[df['log_bldng_ar']>=8, 'log_bldng_ar'] = 7
    
    return df

# %%
# ttl_grnd_flr 전처리 함수
def pre_ttl_grnd_flr(df):
    df.loc[((df['ttl_grnd_flr']>=6) & (df['ttl_grnd_flr']<30)), 'ttl_grnd_flr'] = 6
    df.loc[df['ttl_grnd_flr']>=30, 'ttl_grnd_flr'] = 30
    df['ttl_grnd_flr'].fillna(1, inplace=True)
    
    return df

# %%
# ttl_dwn_flr 전처리 함수
def pre_ttl_dwn_flr(df):
    df.loc[df['ttl_dwn_flr']>=10,'ttl_dwn_flr'] = 10
    df['ttl_dwn_flr'].fillna(0, inplace=True)
    
    return df

# %%
# sft_emrgnc_bll_dstnc 전처리 함수
def get_group_sft_bll(data):
    if data < 50:
        return 0
    elif data < 100:
        return 50
    elif data < 150:
        return 100
    elif data < 200:
        return 150
    elif data < 250:
        return 200
    elif data < 300:
        return 250
    else:
        return 300

def pre_sft_emrgnc_bll_dstnc(df):
    df['sqrt_sft_emrgnc_bll_dstnc'] = df['sft_emrgnc_bll_dstnc'].apply(lambda x:np.sqrt(x))
    df['sqrt_sft_emrgnc_bll_dstnc'] = df['sqrt_sft_emrgnc_bll_dstnc'].apply(get_group_sft_bll)
    df.drop('sft_emrgnc_bll_dstnc', axis=1, inplace=True)
    
    return df

# %%
# no_tbc_zn_dstnc 전처리 함수
def get_group_no_tbc(data):
    if data < 1:
        return 0
    elif data < 3:
        return 1
    elif data < 5:
        return 3
    elif data < 7:
        return 5
    elif data < 9:
        return 7
    else:
        return 9

def pre_no_tbc_zn_dstnc(df):
    df['log_no_tbc_zn_dstnc'] = df['no_tbc_zn_dstnc'].apply(lambda x:np.log(x+1))
    df['log_no_tbc_zn_dstnc'] = df['log_no_tbc_zn_dstnc'].apply(get_group_no_tbc)
    df.drop('no_tbc_zn_dstnc', axis=1, inplace=True)
    
    return df

# %% [markdown]
# #### 2.2.2. 전처리 통합 함수 정의

# %%
def preprocessing(df):
    pre_bldng_archtctr(df)
    pre_bldng_us_clssfctn(df)
    pre_rd_sd_nm(df)
    pre_fr_wthr_fclt_dstnc(df)
    pre_dt_of_fr(df)
    pre_hmdt(df)
    pre_emd_nm(df)
    pre_bldng_ar_prc(df)
    pre_dt_of_athrztn(df)
    pre2_dt_of_athrztn(df)
    pre_rgnl_ar_nm(df)
    pre_lnd_us_sttn(df)
    pre_ttl_ar(df)
    pre_bldng_ar(df)
    pre_ttl_grnd_flr(df)
    pre_ttl_dwn_flr(df)
    pre_sft_emrgnc_bll_dstnc(df)
    pre_no_tbc_zn_dstnc(df)
    
    return df

# %% [markdown]
# ### 2.3. 함수 적용

# %%
preprocessing(df_train)
preprocessing(df_test)
# Out:
#       bldng_archtctr  dt_of_athrztn  ttl_grnd_flr  ttl_dwn_flr  \
# 0                  0             21           1.0          0.0
# 1                 12             18           1.0          0.0
# 2                  0             27           6.0          0.0
# 3                  0             27           3.0          0.0
# 4                  0             28           3.0          0.0
# 5                 16             19           2.0          0.0
# 6                 16             27           4.0          0.0
# 7                 11             89           1.0          0.0
# 8                  8             18           1.0          0.0
# 9                 16             24           2.0          0.0
# 10                16             18           2.0          0.0
# 11                 0             27           2.0          0.0
# 12                 2             17           1.0          0.0
# 13                16              8           3.0          0.0
# 14                11             94           1.0          0.0
# 15                12              7           2.0          0.0
# 16                14              6           6.0          1.0
# 17                12             24           2.0          0.0
# 18                16             14           2.0          0.0
# 19                 8             28           2.0          0.0
# 20                12              4           2.0          0.0
# 21                16             22           1.0          0.0
# 22                 0             27           1.0          0.0
# 23                16             18           2.0          0.0
# 24                 9              8           1.0          0.0
# 25                11             98           1.0          0.0
# 26                 2             11           1.0          0.0
# 27                 8             85           2.0          0.0
# 28                16              8           3.0          0.0
# 29                16              7           2.0          0.0
# ...              ...            ...           ...          ...
# 2927              16             25           1.0          0.0
# 2928              12             18           3.0          0.0
# 2929               0             29           2.0          1.0
# 2930               0             16           1.0          0.0
# 2931              11             76           1.0          0.0
# 2932              16             17           2.0          0.0
# 2933              16             45           1.0          0.0
# 2934               8              8           2.0          0.0
# 2935               8             19           1.0          0.0
# 2936               8             18           1.0          0.0
# 2937               5             86           1.0          0.0
# 2938               8             15           1.0          0.0
# 2939              16             11           2.0          0.0
# 2940              16              3           1.0          0.0
# 2941              16             17           4.0          1.0
# 2942               0             27           2.0          0.0
# 2943              16             10           1.0          0.0
# 2944              16             19           3.0          0.0
# 2945              16             21           1.0          0.0
# 2946               0             26           1.0          0.0
# 2947              16             27           2.0          0.0
# 2948              12             22           2.0          0.0
# 2949              12             18           1.0          0.0
# 2950              12              6           1.0          0.0
# 2951              16             17           5.0          1.0
# 2952              16             18           3.0          0.0
# 2953               0             27           1.0          0.0
# 2954              16              7           3.0          0.0
# 2955               2             10           1.0          0.0
# 2956              16             21           3.0          1.0
#
#       bldng_us_clssfctn  hmdt  rd_sd_nm  emd_nm  bldng_ar_prc  \
# 0                     0  20.0         6       1          1078
# 1                     2  62.0         9       8           851
# 2                     0  97.0         6      14           953
# 3                     0  63.0         6      14           953
# 4                     0  28.0         6      16           344
# 5                     7  66.0         9       4          1275
# 6                     7  93.0         4       0           723
# 7                     7  35.0         6      13           816
# 8                     7  72.0         7       1           709
# 9                     6  51.0         6      15           891
# 10                    2  80.0         8      17          1143
# 11                    0  52.0         6      14           953
# 12                    7  46.0        11      15          1908
# 13                    7  52.0         9      11          1142
# 14                    7  92.0         7      15          2042
# 15                    2  64.0         6      12          1228
# 16                    5  31.0         2      10          1337
# 17                    2  27.0         6      13          1136
# 18                    7  40.0         9      16          2025
# 19                    7  82.0         6       6           743
# 20                    6  54.0         6      12          1228
# 21                    7  47.0         6       9          1659
# 22                    0  40.0         6      14           286
# 23                    7  57.0         9      18          1661
# 24                    6  56.0         2      11          1495
# 25                    7  77.0         6      13          2101
# 26                    7  65.0        10       9          2082
# 27                    7  45.0         7       8           535
# 28                    7  79.0         9       4          1143
# 29                    6  97.0         9       8           851
# ...                 ...   ...       ...     ...           ...
# 2927                  6  31.0         9      17          1143
# 2928                  6  56.0         6       7           842
# 2929                  0  52.0         7       8           733
# 2930                  0  47.0         6      10          1991
# 2931                  7  29.0         6      14           410
# 2932                  6  20.0         9      10          1337
# 2933                  0  96.0         9      14           953
# 2934                  6  83.0         6       1          1078
# 2935                  7  58.0         6       1           726
# 2936                  7  84.0         6       0          1942
# 2937                  7  71.0         6      16          1168
# 2938                  7  32.0         4      16          1022
# 2939                  7  77.0         9      14          1177
# 2940                  0  94.0         9       0          1142
# 2941                  6  62.0         2      10          1337
# 2942                  0  97.0         8      14           953
# 2943                  7  37.0         9      14          2014
# 2944                  6  83.0         9       3           926
# 2945                  0  47.0         9       9          1393
# 2946                  0  44.0         6       9          1393
# 2947                  7  92.0         9       0           450
# 2948                  2  37.0         9       8           851
# 2949                  2  80.0         4      16           878
# 2950                  2  86.0         8      12          1228
# 2951                  5  17.0        12      10          1337
# 2952                  7  70.0         6       0          1120
# 2953                  0  35.0         7      14          2496
# 2954                  7  78.0         8       0          1147
# 2955                  6  47.0        11       6           865
# 2956                  1  91.0        10      15          1369
#
#       fr_wthr_fclt_dstnc  ...  fr_yn  hour  rgnl_ar_nm_cat  rgnl_ar_nm_cat2  \
# 0                   11.0  ...    NaN    15               7                2
# 1                   29.0  ...    NaN    18               2                2
# 2                    5.0  ...    NaN     6               1                1
# 3                   25.0  ...    NaN    23               1                1
# 4                    9.0  ...    NaN    11               2                2
# 5                   25.0  ...    NaN    17               6                6
# 6                    0.0  ...    NaN     4               6                6
# 7                   21.0  ...    NaN    13               6                6
# 8                   12.0  ...    NaN    18               6                6
# 9                   13.0  ...    NaN    15               6                6
# 10                   6.0  ...    NaN     4               1                1
# 11                   4.0  ...    NaN    10               5                5
# 12                   7.0  ...    NaN    16               6                6
# 13                   8.0  ...    NaN     5               6                6
# 14                  18.0  ...    NaN    13               6                6
# 15                  18.0  ...    NaN    19               1                1
# 16                  10.0  ...    NaN    19               5                5
# 17                  47.0  ...    NaN    18               2                2
# 18                   2.0  ...    NaN    12               2                2
# 19                   7.0  ...    NaN    11               6                6
# 20                  46.0  ...    NaN    13               6                6
# 21                  13.0  ...    NaN     3               6                6
# 22                  94.0  ...    NaN     4               0                0
# 23                   2.0  ...    NaN    19               5                5
# 24                   9.0  ...    NaN    13               5                5
# 25                  34.0  ...    NaN     1               6                6
# 26                   3.0  ...    NaN    12               6                6
# 27                  29.0  ...    NaN     0               2                2
# 28                   8.0  ...    NaN    10               6                6
# 29                  25.0  ...    NaN     7               2                2
# ...                  ...  ...    ...   ...             ...              ...
# 2927                 9.0  ...    NaN    15               1                1
# 2928                40.0  ...    NaN    13               2                2
# 2929                45.0  ...    NaN    11               2                2
# 2930                46.0  ...    NaN     3               7                2
# 2931                 7.0  ...    NaN    12               6                6
# 2932                12.0  ...    NaN    18               3                3
# 2933                 3.0  ...    NaN    13               5                5
# 2934                28.0  ...    NaN     8               6                6
# 2935                43.0  ...    NaN     4               6                6
# 2936                 6.0  ...    NaN    10               6                6
# 2937                24.0  ...    NaN    22               2                2
# 2938                 9.0  ...    NaN    22               2                2
# 2939                 3.0  ...    NaN    19               6                6
# 2940                18.0  ...    NaN     5               6                6
# 2941                13.0  ...    NaN     4               6                6
# 2942                 9.0  ...    NaN    15               1                1
# 2943                 3.0  ...    NaN    14               6                6
# 2944                11.0  ...    NaN     9               6                6
# 2945                10.0  ...    NaN     4               5                5
# 2946                 8.0  ...    NaN    19               5                5
# 2947                 7.0  ...    NaN     7               6                6
# 2948                52.0  ...    NaN    16               2                2
# 2949                 4.0  ...    NaN    10               2                2
# 2950                32.0  ...    NaN     6               1                1
# 2951                14.0  ...    NaN    16               3                3
# 2952                 6.0  ...    NaN    19               6                6
# 2953                37.0  ...    NaN    18               2                2
# 2954                 7.0  ...    NaN    15               6                6
# 2955                10.0  ...    NaN    23               1                1
# 2956                 5.0  ...    NaN    23               6                6
#
#       lnd_us_sttn_cat  lnd_us_sttn_cat2  log_ttl_ar  log_bldng_ar  \
# 0                   9                 6           0             0
# 1                   1                 1           6             5
# 2                   1                 1           7             7
# 3                   1                 1           6             5
# 4                   5                 5           6             5
# 5                   6                 6           5             4
# 6                   6                 6           6             4
# 7                   6                 6           4             4
# 8                   6                 6           4             4
# 9                   6                 6           5             5
# 10                  1                 1           6             5
# 11                  3                 3           4             4
# 12                  3                 3           5             5
# 13                  7                 7           5             4
# 14                  6                 6           4             4
# 15                  1                 1           6             5
# 16                  3                 3           6             5
# 17                  1                 1           6             6
# 18                  6                 6           4             4
# 19                  6                 6           5             4
# 20                  5                 5           5             5
# 21                  6                 6           5             5
# 22                  6                 6           4             4
# 23                  3                 3           6             5
# 24                  3                 3           6             5
# 25                  6                 6           3             3
# 26                  7                 7           4             4
# 27                  6                 6           4             4
# 28                  7                 7           5             5
# 29                  3                 3           6             5
# ...               ...               ...         ...           ...
# 2927                1                 1           5             5
# 2928                1                 1           6             5
# 2929                6                 6           5             4
# 2930                9                 6           5             4
# 2931                6                 6           4             4
# 2932                3                 3           6             5
# 2933                6                 6           6             5
# 2934                6                 6           4             4
# 2935                6                 6           4             4
# 2936                6                 6           4             4
# 2937                6                 6           3             3
# 2938                6                 6           4             4
# 2939                7                 7           5             4
# 2940                6                 6           6             5
# 2941                3                 3           6             6
# 2942                1                 1           6             5
# 2943                7                 7           4             4
# 2944                3                 3           6             4
# 2945                3                 3           6             5
# 2946                6                 6           4             4
# 2947                6                 6           5             4
# 2948                1                 1           6             6
# 2949                1                 1           5             5
# 2950                1                 1           6             5
# 2951                0                 0           7             7
# 2952                6                 6           5             4
# 2953                6                 6           3             3
# 2954                6                 6           6             5
# 2955                1                 1           5             5
# 2956                6                 6           6             6
#
#       sqrt_sft_emrgnc_bll_dstnc  log_no_tbc_zn_dstnc
# 0                           100                    7
# 1                            50                    7
# 2                             0                    5
# 3                            50                    7
# 4                            50                    7
# 5                             0                    5
# 6                             0                    3
# 7                             0                    5
# 8                            50                    7
# 9                             0                    5
# 10                            0                    5
# 11                            0                    5
# 12                            0                    3
# 13                            0                    5
# 14                            0                    5
# 15                            0                    5
# 16                            0                    5
# 17                           50                    3
# 18                           50                    5
# 19                            0                    3
# 20                            0                    5
# 21                            0                    3
# 22                           50                    7
# 23                            0                    5
# 24                            0                    3
# 25                            0                    5
# 26                            0                    3
# 27                           50                    7
# 28                            0                    3
# 29                           50                    5
# ...                         ...                  ...
# 2927                          0                    5
# 2928                         50                    7
# 2929                         50                    5
# 2930                          0                    5
# 2931                          0                    5
# 2932                          0                    5
# 2933                          0                    5
# 2934                          0                    7
# 2935                        100                    7
# 2936                          0                    3
# 2937                         50                    7
# 2938                         50                    5
# 2939                          0                    5
# 2940                          0                    5
# 2941                          0                    5
# 2942                          0                    5
# 2943                          0                    5
# 2944                          0                    5
# 2945                          0                    5
# 2946                          0                    5
# 2947                          0                    3
# 2948                         50                    7
# 2949                         50                    5
# 2950                          0                    5
# 2951                          0                    5
# 2952                          0                    5
# 2953                          0                    5
# 2954                          0                    3
# 2955                          0                    5
# 2956                          0                    5
#
# [2957 rows x 22 columns]

# %%
df_train.head()
# Out:
#    bldng_archtctr  dt_of_athrztn  ttl_grnd_flr  ttl_dwn_flr  \
# 0               9             42           1.0          0.0
# 1               0             18           1.0          0.0
# 2              16             19           5.0          0.0
# 3              11             83           1.0          0.0
# 4               0             38           1.0          0.0
#
#    bldng_us_clssfctn  hmdt  rd_sd_nm  emd_nm  bldng_ar_prc  \
# 0                  7  96.0         7     201           580
# 1                  0  74.0         6       1           123
# 2                  7  21.0        11     201           618
# 3                  7  91.0         7     174           720
# 4                  0  89.0         7     201           580
#
#    fr_wthr_fclt_dstnc  ...  fr_yn  hour  rgnl_ar_nm_cat  rgnl_ar_nm_cat2  \
# 0                13.0  ...      1     5               3                3
# 1                49.0  ...      0     8               2                2
# 2                14.0  ...      1    14               8                8
# 3               158.0  ...      0     5               8                8
# 4                60.0  ...      0     5               7                7
#
#    lnd_us_sttn_cat  lnd_us_sttn_cat2  log_ttl_ar  log_bldng_ar  \
# 0                7                 7           4             4
# 1                7                 7           3             3
# 2                7                 7           6             5
# 3                7                 7           3             3
# 4                5                 5           0             0
#
#    sqrt_sft_emrgnc_bll_dstnc  log_no_tbc_zn_dstnc
# 0                        150                    3
# 1                        100                    7
# 2                        150                    3
# 3                         50                    5
# 4                        150                    5
#
# [5 rows x 22 columns]

# %%
df_test.head()
# Out:
#    bldng_archtctr  dt_of_athrztn  ttl_grnd_flr  ttl_dwn_flr  \
# 0               0             21           1.0          0.0
# 1              12             18           1.0          0.0
# 2               0             27           6.0          0.0
# 3               0             27           3.0          0.0
# 4               0             28           3.0          0.0
#
#    bldng_us_clssfctn  hmdt  rd_sd_nm  emd_nm  bldng_ar_prc  \
# 0                  0  20.0         6       1          1078
# 1                  2  62.0         9       8           851
# 2                  0  97.0         6      14           953
# 3                  0  63.0         6      14           953
# 4                  0  28.0         6      16           344
#
#    fr_wthr_fclt_dstnc  ...  fr_yn  hour  rgnl_ar_nm_cat  rgnl_ar_nm_cat2  \
# 0                11.0  ...    NaN    15               7                2
# 1                29.0  ...    NaN    18               2                2
# 2                 5.0  ...    NaN     6               1                1
# 3                25.0  ...    NaN    23               1                1
# 4                 9.0  ...    NaN    11               2                2
#
#    lnd_us_sttn_cat  lnd_us_sttn_cat2  log_ttl_ar  log_bldng_ar  \
# 0                9                 6           0             0
# 1                1                 1           6             5
# 2                1                 1           7             7
# 3                1                 1           6             5
# 4                5                 5           6             5
#
#    sqrt_sft_emrgnc_bll_dstnc  log_no_tbc_zn_dstnc
# 0                        100                    7
# 1                         50                    7
# 2                          0                    5
# 3                         50                    7
# 4                         50                    7
#
# [5 rows x 22 columns]

# %%
df_train.isna().sum()
# Out:
# bldng_archtctr               0
# dt_of_athrztn                0
# ttl_grnd_flr                 0
# ttl_dwn_flr                  0
# bldng_us_clssfctn            0
# hmdt                         0
# rd_sd_nm                     0
# emd_nm                       0
# bldng_ar_prc                 0
# fr_wthr_fclt_dstnc           0
# mlt_us_yn                    0
# cctv_in_100m                 0
# fr_yn                        0
# hour                         0
# rgnl_ar_nm_cat               0
# rgnl_ar_nm_cat2              0
# lnd_us_sttn_cat              0
# lnd_us_sttn_cat2             0
# log_ttl_ar                   0
# log_bldng_ar                 0
# sqrt_sft_emrgnc_bll_dstnc    0
# log_no_tbc_zn_dstnc          0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# bldng_archtctr                  0
# dt_of_athrztn                   0
# ttl_grnd_flr                    0
# ttl_dwn_flr                     0
# bldng_us_clssfctn               0
# hmdt                            0
# rd_sd_nm                        0
# emd_nm                          0
# bldng_ar_prc                    0
# fr_wthr_fclt_dstnc              0
# mlt_us_yn                       0
# cctv_in_100m                    0
# fr_yn                        2957
# hour                            0
# rgnl_ar_nm_cat                  0
# rgnl_ar_nm_cat2                 0
# lnd_us_sttn_cat                 0
# lnd_us_sttn_cat2                0
# log_ttl_ar                      0
# log_bldng_ar                    0
# sqrt_sft_emrgnc_bll_dstnc       0
# log_no_tbc_zn_dstnc             0
# dtype: int64

# %%
df_train.info(True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59199 entries, 0 to 59198
# Data columns (total 22 columns):
# bldng_archtctr               59199 non-null int32
# dt_of_athrztn                59199 non-null int32
# ttl_grnd_flr                 59199 non-null float64
# ttl_dwn_flr                  59199 non-null float64
# bldng_us_clssfctn            59199 non-null int32
# hmdt                         59199 non-null float64
# rd_sd_nm                     59199 non-null int32
# emd_nm                       59199 non-null int32
# bldng_ar_prc                 59199 non-null int32
# fr_wthr_fclt_dstnc           59199 non-null float64
# mlt_us_yn                    59199 non-null int64
# cctv_in_100m                 59199 non-null int64
# fr_yn                        59199 non-null int64
# hour                         59199 non-null int64
# rgnl_ar_nm_cat               59199 non-null int32
# rgnl_ar_nm_cat2              59199 non-null int32
# lnd_us_sttn_cat              59199 non-null int32
# lnd_us_sttn_cat2             59199 non-null int32
# log_ttl_ar                   59199 non-null int64
# log_bldng_ar                 59199 non-null int64
# sqrt_sft_emrgnc_bll_dstnc    59199 non-null int64
# log_no_tbc_zn_dstnc          59199 non-null int64
# dtypes: float64(4), int32(10), int64(8)
# memory usage: 7.7 MB

# %%
df_test.isna().sum()
# Out:
# bldng_archtctr                  0
# dt_of_athrztn                   0
# ttl_grnd_flr                    0
# ttl_dwn_flr                     0
# bldng_us_clssfctn               0
# hmdt                            0
# rd_sd_nm                        0
# emd_nm                          0
# bldng_ar_prc                    0
# fr_wthr_fclt_dstnc              0
# mlt_us_yn                       0
# cctv_in_100m                    0
# fr_yn                        2957
# hour                            0
# rgnl_ar_nm_cat                  0
# rgnl_ar_nm_cat2                 0
# lnd_us_sttn_cat                 0
# lnd_us_sttn_cat2                0
# log_ttl_ar                      0
# log_bldng_ar                    0
# sqrt_sft_emrgnc_bll_dstnc       0
# log_no_tbc_zn_dstnc             0
# dtype: int64

# %% [markdown]
# ## 3. 모델 학습

# %%
from sklearn.metrics import accuracy_score, precision_score , recall_score , confusion_matrix, f1_score

# 평가 지표를 계산하는 함수
def get_clf_eval(y_test , pred):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1=f1_score(y_test,pred)
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f} F1:{3:.4f}'.format(accuracy , precision ,recall,f1))

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

target = df_train['fr_yn']
df_train = df_train.drop(['fr_yn'], axis=1, inplace=False)

smote = SMOTE(random_state=0)
X_train, X_test, y_train, y_test = train_test_split(df_train, target, test_size=0.16, random_state=156)
X_train_over, y_train_over = smote.fit_sample(X_train, y_train)
lgbm_wrapper = LGBMClassifier(n_estimators=500)
evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train_over, y_train_over, early_stopping_rounds=100, eval_metric='logloss', eval_set=evals, verbose=True)
preds = lgbm_wrapper.predict(X_test)
get_clf_eval(y_test, preds)
# Out:
# [1]	valid_0's binary_logloss: 0.636475
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.589589
# [3]	valid_0's binary_logloss: 0.54976
# [4]	valid_0's binary_logloss: 0.516224
# [5]	valid_0's binary_logloss: 0.487948
# [6]	valid_0's binary_logloss: 0.462606
# [7]	valid_0's binary_logloss: 0.441176
# [8]	valid_0's binary_logloss: 0.422163
# [9]	valid_0's binary_logloss: 0.404677
# [10]	valid_0's binary_logloss: 0.389113
# [11]	valid_0's binary_logloss: 0.375673
# [12]	valid_0's binary_logloss: 0.363443
# [13]	valid_0's binary_logloss: 0.352765
# [14]	valid_0's binary_logloss: 0.343021
# [15]	valid_0's binary_logloss: 0.334884
# [16]	valid_0's binary_logloss: 0.326816
# [17]	valid_0's binary_logloss: 0.3196
# [18]	valid_0's binary_logloss: 0.312789
# [19]	valid_0's binary_logloss: 0.305475
# [20]	valid_0's binary_logloss: 0.29988
# [21]	valid_0's binary_logloss: 0.294256
# [22]	valid_0's binary_logloss: 0.290269
# [23]	valid_0's binary_logloss: 0.285424
# [24]	valid_0's binary_logloss: 0.281732
# [25]	valid_0's binary_logloss: 0.278196
# [26]	valid_0's binary_logloss: 0.275122
# [27]	valid_0's binary_logloss: 0.272262
# [28]	valid_0's binary_logloss: 0.269581
# [29]	valid_0's binary_logloss: 0.26696
# [30]	valid_0's binary_logloss: 0.264455
# [31]	valid_0's binary_logloss: 0.26187
# [32]	valid_0's binary_logloss: 0.259372
# [33]	valid_0's binary_logloss: 0.257554
# [34]	valid_0's binary_logloss: 0.2557
# [35]	valid_0's binary_logloss: 0.253953
# [36]	valid_0's binary_logloss: 0.252703
# [37]	valid_0's binary_logloss: 0.251209
# [38]	valid_0's binary_logloss: 0.249972
# [39]	valid_0's binary_logloss: 0.248483
# [40]	valid_0's binary_logloss: 0.247514
# [41]	valid_0's binary_logloss: 0.246742
# [42]	valid_0's binary_logloss: 0.24592
# [43]	valid_0's binary_logloss: 0.245059
# [44]	valid_0's binary_logloss: 0.244102
# [45]	valid_0's binary_logloss: 0.243457
# [46]	valid_0's binary_logloss: 0.242877
# [47]	valid_0's binary_logloss: 0.242225
# [48]	valid_0's binary_logloss: 0.241657
# [49]	valid_0's binary_logloss: 0.241208
# [50]	valid_0's binary_logloss: 0.240431
# [51]	valid_0's binary_logloss: 0.240378
# [52]	valid_0's binary_logloss: 0.240071
# [53]	valid_0's binary_logloss: 0.239787
# [54]	valid_0's binary_logloss: 0.239477
# [55]	valid_0's binary_logloss: 0.239221
# [56]	valid_0's binary_logloss: 0.238808
# [57]	valid_0's binary_logloss: 0.238577
# [58]	valid_0's binary_logloss: 0.23832
# [59]	valid_0's binary_logloss: 0.238009
# [60]	valid_0's binary_logloss: 0.237722
# [61]	valid_0's binary_logloss: 0.23752
# [62]	valid_0's binary_logloss: 0.237304
# [63]	valid_0's binary_logloss: 0.237052
# [64]	valid_0's binary_logloss: 0.236941
# [65]	valid_0's binary_logloss: 0.236826
# [66]	valid_0's binary_logloss: 0.23673
# [67]	valid_0's binary_logloss: 0.236521
# [68]	valid_0's binary_logloss: 0.236401
# [69]	valid_0's binary_logloss: 0.236286
# [70]	valid_0's binary_logloss: 0.236172
# [71]	valid_0's binary_logloss: 0.235954
# [72]	valid_0's binary_logloss: 0.235757
# [73]	valid_0's binary_logloss: 0.235542
# [74]	valid_0's binary_logloss: 0.235463
# [75]	valid_0's binary_logloss: 0.235308
# [76]	valid_0's binary_logloss: 0.235259
# [77]	valid_0's binary_logloss: 0.235277
# [78]	valid_0's binary_logloss: 0.235187
# [79]	valid_0's binary_logloss: 0.235194
# [80]	valid_0's binary_logloss: 0.235261
# [81]	valid_0's binary_logloss: 0.235142
# [82]	valid_0's binary_logloss: 0.235061
# [83]	valid_0's binary_logloss: 0.234955
# [84]	valid_0's binary_logloss: 0.234939
# [85]	valid_0's binary_logloss: 0.235013
# [86]	valid_0's binary_logloss: 0.234714
# [87]	valid_0's binary_logloss: 0.234644
# [88]	valid_0's binary_logloss: 0.234573
# [89]	valid_0's binary_logloss: 0.234536
# [90]	valid_0's binary_logloss: 0.234562
# [91]	valid_0's binary_logloss: 0.234584
# [92]	valid_0's binary_logloss: 0.23459
# [93]	valid_0's binary_logloss: 0.234572
# [94]	valid_0's binary_logloss: 0.234532
# [95]	valid_0's binary_logloss: 0.234439
# [96]	valid_0's binary_logloss: 0.234488
# [97]	valid_0's binary_logloss: 0.23457
# [98]	valid_0's binary_logloss: 0.234552
# [99]	valid_0's binary_logloss: 0.234558
# [100]	valid_0's binary_logloss: 0.234504
# [101]	valid_0's binary_logloss: 0.234477
# [102]	valid_0's binary_logloss: 0.234475
# [103]	valid_0's binary_logloss: 0.234377
# [104]	valid_0's binary_logloss: 0.234435
# [105]	valid_0's binary_logloss: 0.23444
# [106]	valid_0's binary_logloss: 0.234456
# [107]	valid_0's binary_logloss: 0.234443
# [108]	valid_0's binary_logloss: 0.234347
# [109]	valid_0's binary_logloss: 0.234384
# [110]	valid_0's binary_logloss: 0.234324
# [111]	valid_0's binary_logloss: 0.234228
# [112]	valid_0's binary_logloss: 0.234116
# [113]	valid_0's binary_logloss: 0.234116
# [114]	valid_0's binary_logloss: 0.234134
# [115]	valid_0's binary_logloss: 0.234149
# [116]	valid_0's binary_logloss: 0.23413
# [117]	valid_0's binary_logloss: 0.234204
# [118]	valid_0's binary_logloss: 0.234091
# [119]	valid_0's binary_logloss: 0.234119
# [120]	valid_0's binary_logloss: 0.234065
# [121]	valid_0's binary_logloss: 0.233936
# [122]	valid_0's binary_logloss: 0.233826
# [123]	valid_0's binary_logloss: 0.233785
# [124]	valid_0's binary_logloss: 0.233673
# [125]	valid_0's binary_logloss: 0.233624
# [126]	valid_0's binary_logloss: 0.233664
# [127]	valid_0's binary_logloss: 0.233652
# [128]	valid_0's binary_logloss: 0.23367
# [129]	valid_0's binary_logloss: 0.233637
# [130]	valid_0's binary_logloss: 0.233783
# [131]	valid_0's binary_logloss: 0.233743
# [132]	valid_0's binary_logloss: 0.233763
# [133]	valid_0's binary_logloss: 0.233764
# [134]	valid_0's binary_logloss: 0.233727
# [135]	valid_0's binary_logloss: 0.233619
# [136]	valid_0's binary_logloss: 0.233666
# [137]	valid_0's binary_logloss: 0.233527
# [138]	valid_0's binary_logloss: 0.233465
# [139]	valid_0's binary_logloss: 0.233389
# [140]	valid_0's binary_logloss: 0.233396
# [141]	valid_0's binary_logloss: 0.233383
# [142]	valid_0's binary_logloss: 0.233398
# [143]	valid_0's binary_logloss: 0.233279
# [144]	valid_0's binary_logloss: 0.233263
# [145]	valid_0's binary_logloss: 0.233281
# [146]	valid_0's binary_logloss: 0.23331
# [147]	valid_0's binary_logloss: 0.23334
# [148]	valid_0's binary_logloss: 0.233293
# [149]	valid_0's binary_logloss: 0.233361
# [150]	valid_0's binary_logloss: 0.233416
# [151]	valid_0's binary_logloss: 0.233374
# [152]	valid_0's binary_logloss: 0.233366
# [153]	valid_0's binary_logloss: 0.233317
# [154]	valid_0's binary_logloss: 0.233336
# [155]	valid_0's binary_logloss: 0.233355
# [156]	valid_0's binary_logloss: 0.233344
# [157]	valid_0's binary_logloss: 0.233294
# [158]	valid_0's binary_logloss: 0.233345
# [159]	valid_0's binary_logloss: 0.233352
# [160]	valid_0's binary_logloss: 0.233303
# [161]	valid_0's binary_logloss: 0.233307
# [162]	valid_0's binary_logloss: 0.233222
# [163]	valid_0's binary_logloss: 0.233246
# [164]	valid_0's binary_logloss: 0.233248
# [165]	valid_0's binary_logloss: 0.233279
# [166]	valid_0's binary_logloss: 0.233261
# [167]	valid_0's binary_logloss: 0.233167
# [168]	valid_0's binary_logloss: 0.233135
# [169]	valid_0's binary_logloss: 0.233075
# [170]	valid_0's binary_logloss: 0.232977
# [171]	valid_0's binary_logloss: 0.23293
# [172]	valid_0's binary_logloss: 0.232912
# [173]	valid_0's binary_logloss: 0.23293
# [174]	valid_0's binary_logloss: 0.232962
# [175]	valid_0's binary_logloss: 0.23289
# [176]	valid_0's binary_logloss: 0.232876
# [177]	valid_0's binary_logloss: 0.232866
# [178]	valid_0's binary_logloss: 0.232905
# [179]	valid_0's binary_logloss: 0.232818
# [180]	valid_0's binary_logloss: 0.232784
# [181]	valid_0's binary_logloss: 0.232688
# [182]	valid_0's binary_logloss: 0.23262
# [183]	valid_0's binary_logloss: 0.232582
# [184]	valid_0's binary_logloss: 0.232611
# [185]	valid_0's binary_logloss: 0.232626
# [186]	valid_0's binary_logloss: 0.232689
# [187]	valid_0's binary_logloss: 0.232678
# [188]	valid_0's binary_logloss: 0.232654
# [189]	valid_0's binary_logloss: 0.232631
# [190]	valid_0's binary_logloss: 0.23263
# [191]	valid_0's binary_logloss: 0.232599
# [192]	valid_0's binary_logloss: 0.232593
# [193]	valid_0's binary_logloss: 0.232627
# [194]	valid_0's binary_logloss: 0.232713
# [195]	valid_0's binary_logloss: 0.232668
# [196]	valid_0's binary_logloss: 0.232622
# [197]	valid_0's binary_logloss: 0.23265
# [198]	valid_0's binary_logloss: 0.232653
# [199]	valid_0's binary_logloss: 0.232634
# [200]	valid_0's binary_logloss: 0.232692
# [201]	valid_0's binary_logloss: 0.232664
# [202]	valid_0's binary_logloss: 0.232717
# [203]	valid_0's binary_logloss: 0.232823
# [204]	valid_0's binary_logloss: 0.232806
# [205]	valid_0's binary_logloss: 0.232874
# [206]	valid_0's binary_logloss: 0.232879
# [207]	valid_0's binary_logloss: 0.232856
# [208]	valid_0's binary_logloss: 0.232861
# [209]	valid_0's binary_logloss: 0.232797
# [210]	valid_0's binary_logloss: 0.232864
# [211]	valid_0's binary_logloss: 0.232871
# [212]	valid_0's binary_logloss: 0.232878
# [213]	valid_0's binary_logloss: 0.23281
# [214]	valid_0's binary_logloss: 0.2328
# [215]	valid_0's binary_logloss: 0.232819
# [216]	valid_0's binary_logloss: 0.232837
# [217]	valid_0's binary_logloss: 0.232851
# [218]	valid_0's binary_logloss: 0.232824
# [219]	valid_0's binary_logloss: 0.232898
# [220]	valid_0's binary_logloss: 0.232909
# [221]	valid_0's binary_logloss: 0.232861
# [222]	valid_0's binary_logloss: 0.232942
# [223]	valid_0's binary_logloss: 0.232952
# [224]	valid_0's binary_logloss: 0.232927
# [225]	valid_0's binary_logloss: 0.232917
# [226]	valid_0's binary_logloss: 0.233049
# [227]	valid_0's binary_logloss: 0.233035
# [228]	valid_0's binary_logloss: 0.233029
# [229]	valid_0's binary_logloss: 0.233011
# [230]	valid_0's binary_logloss: 0.232949
# [231]	valid_0's binary_logloss: 0.232937
# [232]	valid_0's binary_logloss: 0.232939
# [233]	valid_0's binary_logloss: 0.232871
# [234]	valid_0's binary_logloss: 0.23293
# [235]	valid_0's binary_logloss: 0.232953
# [236]	valid_0's binary_logloss: 0.232932
# [237]	valid_0's binary_logloss: 0.232975
# [238]	valid_0's binary_logloss: 0.232974
# [239]	valid_0's binary_logloss: 0.232993
# [240]	valid_0's binary_logloss: 0.232988
# [241]	valid_0's binary_logloss: 0.232967
# [242]	valid_0's binary_logloss: 0.233
# [243]	valid_0's binary_logloss: 0.233036
# [244]	valid_0's binary_logloss: 0.233059
# [245]	valid_0's binary_logloss: 0.233095
# [246]	valid_0's binary_logloss: 0.233086
# [247]	valid_0's binary_logloss: 0.233085
# [248]	valid_0's binary_logloss: 0.233104
# [249]	valid_0's binary_logloss: 0.233031
# [250]	valid_0's binary_logloss: 0.233089
# [251]	valid_0's binary_logloss: 0.233048
# [252]	valid_0's binary_logloss: 0.233045
# [253]	valid_0's binary_logloss: 0.233082
# [254]	valid_0's binary_logloss: 0.233117
# [255]	valid_0's binary_logloss: 0.233143
# [256]	valid_0's binary_logloss: 0.233258
# [257]	valid_0's binary_logloss: 0.2333
# [258]	valid_0's binary_logloss: 0.233268
# [259]	valid_0's binary_logloss: 0.233221
# [260]	valid_0's binary_logloss: 0.233186
# [261]	valid_0's binary_logloss: 0.233262
# [262]	valid_0's binary_logloss: 0.233255
# [263]	valid_0's binary_logloss: 0.233203
# [264]	valid_0's binary_logloss: 0.233183
# [265]	valid_0's binary_logloss: 0.233147
# [266]	valid_0's binary_logloss: 0.233203
# [267]	valid_0's binary_logloss: 0.2332
# [268]	valid_0's binary_logloss: 0.23318
# [269]	valid_0's binary_logloss: 0.233312
# [270]	valid_0's binary_logloss: 0.233306
# [271]	valid_0's binary_logloss: 0.233381
# [272]	valid_0's binary_logloss: 0.233385
# [273]	valid_0's binary_logloss: 0.23331
# [274]	valid_0's binary_logloss: 0.233289
# [275]	valid_0's binary_logloss: 0.233342
# [276]	valid_0's binary_logloss: 0.233326
# [277]	valid_0's binary_logloss: 0.233377
# [278]	valid_0's binary_logloss: 0.233347
# [279]	valid_0's binary_logloss: 0.233385
# [280]	valid_0's binary_logloss: 0.233405
# [281]	valid_0's binary_logloss: 0.233466
# [282]	valid_0's binary_logloss: 0.2335
# [283]	valid_0's binary_logloss: 0.233513
# Early stopping, best iteration is:
# [183]	valid_0's binary_logloss: 0.232582
# 오차 행렬
# [[7997  271]
#  [ 747  457]]
# 정확도: 0.8925, 정밀도: 0.6277, 재현율: 0.3796 F1:0.4731

# %% [markdown]
# ## 4. 예측

# %%
df_test = df_test.drop(['fr_yn'], axis=1, inplace=False)

preds = lgbm_wrapper.predict(df_test)
preds
# Out:
# array([0, 1, 0, ..., 1, 0, 1], dtype=int64)

# %% [markdown]
# ## 5. 제출

# %%
df_pred = pd.DataFrame(preds, columns=['fr_yn'])

binary_str = {0:'N', 1:'Y'}
df_pred['fr_yn'] = df_pred['fr_yn'].map(binary_str)

df_pred
# Out:
#      fr_yn
# 0        N
# 1        Y
# 2        N
# 3        N
# 4        N
# 5        Y
# 6        N
# 7        Y
# 8        Y
# 9        Y
# 10       N
# 11       N
# 12       Y
# 13       Y
# 14       Y
# 15       Y
# 16       Y
# 17       Y
# 18       N
# 19       Y
# 20       Y
# 21       Y
# 22       N
# 23       Y
# 24       Y
# 25       N
# 26       Y
# 27       N
# 28       Y
# 29       N
# ...    ...
# 2927     Y
# 2928     Y
# 2929     N
# 2930     N
# 2931     Y
# 2932     Y
# 2933     Y
# 2934     N
# 2935     N
# 2936     Y
# 2937     N
# 2938     N
# 2939     Y
# 2940     Y
# 2941     Y
# 2942     N
# 2943     Y
# 2944     Y
# 2945     N
# 2946     N
# 2947     Y
# 2948     Y
# 2949     N
# 2950     Y
# 2951     Y
# 2952     Y
# 2953     N
# 2954     Y
# 2955     N
# 2956     Y
#
# [2957 rows x 1 columns]

# %%
df_pred.to_csv('./data/PJT002_submission.csv', mode='w')
